# %% [markdown]
# ## AI, python? 이런저런 try

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai_list =ai.list_models()
k = len(ai_list)
print(ai_list[k-1])  # 리스트 맨 마지막 항목.
# Out:
# google/gemini-3.5-flash

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %% [markdown]
# ## 질문을 받아서 답하는 형태.
# input() 사용자 입력을 기다리는 함수.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai
ques_ask = input()    # your questions here, waiting your action...
# print(ques)
response = ai.generate_text(ques_ask) # " 세계의 경제수도는?")
print(response)
# Out:
# 세계 경제수도는 어딜까?
# 공식적인 국가의 수도는 아니지만, 전 세계 학자들과 전문가들이 인정하는 **세계의 경제 수도는 단연 미국의 '뉴욕(New York City)'**입니다.
#
# 뉴욕이 세계 경제 수도로 불리는 이유는 다음과 같습니다.
#
# ### 1. 글로벌 금융의 중심지 (월스트리트)
# 뉴욕 맨해튼에 위치한 **월스트리트(Wall Street)**는 전 세계 자본이 모이고 분배되는 심장부입니다.
# * **세계 최대의 증권거래소:** 세계에서 가장 규모가 큰 **뉴욕증권거래소(NYSE)**와 기술주 중심의 **나스닥(NASDAQ)**이 모두 뉴욕에 있습니다. 이 두 거래소의 시가총액을 합치면 전 세계 주식 시장의 상당 부분을 차지합니다.
# * **글로벌 금융 기관의 본사:** 골드만삭스, JP모건 체이스, 모건스탠리 등 세계 경제를 움직이는 초거대 투자은행과 자산운용사들이 뉴욕에 본사를 두고 있습니다.
#
# ### 2. 기축통화(달러)의 패권
# 세계에서 가장 힘이 센 통화이자 기축통화인 **미국 달러(USD)**가 가장 활발하게 거래되고 통제되는 곳이 바로 뉴욕입니다. 미국 중앙은행인 연방준비제도(Fed) 내에서 가장 영향력이 강한 **뉴욕 연방준비은행**도 이곳에 있습니다.
#
# ### 3. 실질적인 국제 외교의 중심지
# 경제는 정치 및 외교와 긴밀히 연결되어 있습니다. 국제사회의 중심 기구인 **유엔(UN) 본부**가 뉴욕에 위치해 있어, 경제뿐만 아니라 글로벌 정치·외교의 의사결정이 이루어지는 곳이기도 합니다.
#
# ---
#
# ### 뉴욕을 위협하는 경쟁 도시들 (대안적 경제 수도)
#
# 물론 뉴욕 외에도 강력한 경제적 영향력을 가진 도시들이 있습니다.
#
# * **런던 (영국):** 뉴욕의 가장 강력한 라이벌입니다. **외환 거래량 기준으로는 세계 1위**이며, 유럽과 아시아, 아메리카를 잇는 지리적·시간대적 이점 덕분에 전통적인 국제 금융 허브로 군림하고 있습니다.
# * **상하이 (중국):** 세계 2위 경제 대국인 중국의 경제 수도입니다. 거대한 내수 시장과 제조업 기반을 바탕으로 무섭게 성장하고 있습니다.
# * **도쿄 (일본):** 아시아 최대의 경제 도시 중 하나로, 엄청난 규모의 민간 자산과 대기업들이 밀집해 있습니다.
# * **싱가포르:** 규제 완화, 낮은 세율, 뛰어난 치안을 바탕으로 아시아의 새로운 금융 및 물류 허브로 급부상하고 있습니다.
#
# **요약하자면,** 역사적·규모적·영향력 측면에서 현재까지 명실상부한 세계 경제의 수도는 **미국 뉴욕**입니다.

# %% [markdown]
# ## 모델 지정
# 첫 셀에서 찾아낸 모델 자동 입력, 0번째 혹은 기타. 항목.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of K-things such as food, beauty, pop, etc?", model_name=ai_list[k-1])  # 앞에서 돌려받은 모델 0번, 혹은 맨 마지막 지정.
#response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.5-flash-lite')
print(response)
# Out:
# The undisputed capital of all "K-things" (K-Pop, K-Beauty, K-Food, K-Drama, and K-Fashion) is **Seoul, South Korea**.
#
# While the entire country contributes to the global phenomenon known as *Hallyu* (the Korean Wave), Seoul is the beating heart, creative engine, and global showcase for all of these cultural exports.
#
# Here is a breakdown of how different neighborhoods within Seoul serve as the "micro-capitals" for each K-category:
#
# ---
#
# ### 1. The Capital of K-Pop: Gangnam & Mapo Districts
# Seoul is where the multi-billion dollar K-Pop industry is headquartered.
# *   **The Hubs:** The major entertainment agencies that create global superstars—like **HYBE** (BTS, NewJeans), **SM Entertainment** (AESPA, NCT), **YG Entertainment** (Blackpink), and **JYP Entertainment** (Twice)—are all based in Seoul.
# *   **Key Spots:**
#     *   **K-Star Road (Apgujeong, Gangnam):** A street dedicated to K-Pop, lined with "Gangnamdol" art toys representing different idol groups.
#     *   **Sangam-dong (Mapo):** Home to major broadcasting stations (Mnet, MBC, SBS) where music shows like *M Countdown* are filmed weekly.
#
# ### 2. The Capital of K-Beauty: Myeong-dong & Gangnam
# Seoul is the skincare capital of the world, driving global trends like "glass skin" and snail mucin.
# *   **The Shopping Hub (Myeong-dong):** This district is the holy grail of K-beauty shopping, packed with flagship stores for brands like Innisfree, Laneige, and Nature Republic, alongside giant **Olive Young** stores (the Korean equivalent of Sephora).
# *   **The Treatment Hub (Gangnam/Apgujeong):** Known as the plastic surgery and dermatology capital of Asia. People travel from all over the world to Gangnam for state-of-the-art skin treatments, facials, and cosmetic procedures.
#
# ### 3. The Capital of K-Food: Mapo, Jongno, & the Han River
# From traditional street food to high-end Michelin-starred dining, Seoul is a food-lover's paradise.
# *   **Traditional Street Food:** **Gwangjang Market** (famous for *tteokbokki*, mung bean pancakes, and hand-cut noodles) and **Tongin Market** (where you buy food using traditional brass coins).
# *   **K-BBQ:** The **Mapo district** is famous for having the best Korean BBQ alleys, specializing in grilled pork and beef.
# *   **The Han River Experience:** A quintessential Seoul food experience is ordering delivery fried chicken or cooking "Han River Ramyeon" using instant-cooking machines at convenience stores along the river.
#
# ### 4. The Capital of K-Fashion & Trends: Seongsu-dong & Hongdae
# Seoul’s youth culture dictates what is cool across Asia and beyond.
# *   **Seongsu-dong (The "Brooklyn of Seoul"):** Currently the trendiest neighborhood in Korea. It is the capital of "K-hipsters," filled with industrial-chic cafes, streetwear pop-up shops, and local designer boutiques.
# *   **Hongdae:** Located near several universities, this area is the capital of indie music, street fashion, thrifting, and nightlife.
# *   **Dongdaemun Design Plaza (DDP):** The futuristic hub designed by Zaha Hadid that hosts Seoul Fashion Week.
#
# ### Summary
# If you want to experience the absolute peak of the K-Wave, **Seoul** is the ultimate destination. It is a city where 600-year-old palaces sit right next to futuristic beauty clinics and K-pop stadiums, making it the undeniable global capital of K-Culture.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story about 전국민 무료 점심 프로젝트.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# **제목: 모두의 테이블**
#
# 2030년 봄, 대한민국에는 역사상 가장 엉뚱하고도 따뜻한 법안이 통과되었다. 이름하여 **‘전국민 무료 점심 프로젝트’**, 공식 명칭은 **‘온기(溫氣) 한 끼 법안’**이었다.
#
# 재정 낭비라며 반대하는 목소리도 많았지만, 정부는 단호했다. 기업의 유휴 농지 활용, AI 기반의 식자재 유통 혁신, 그리고 지역 공동체의 자발적 참여를 결합해 예산을 최소화했다. 그렇게 전국의 모든 동사무소와 주민센터, 공공기관의 유휴 공간은 점심시간만 되면 맛있는 냄새를 풍기는 ‘모두의 식당’으로 변신했다.
#
# 프리랜서 디자이너인 민우는 이 프로젝트가 영 미덥지 않았다.
# ‘공짜 밥이 맛있어 봐야 얼마나 맛있겠어? 눈치나 보이겠지.’
#
# 매일 골방에서 모니터만 보며 컵라면이나 배달 음식으로 대충 끼니를 때우던 민우였다. 하지만 그날은 유독 마감 스트레스로 속이 쓰렸고, 냉장고는 텅 비어 있었다. 마침 시계는 12시를 가리키고 있었다. 민우는 밑져야 본전이라는 생각으로 모자를 눌러쓰고 집 앞 ‘망원 3동 모두의 식당’으로 향했다.
#
# 식당 문을 열자, 시큼하고 구수한 청국장 냄새와 달콤한 제육볶음 냄새가 민우의 코끝을 간질였다. 식당 안은 생각보다 훨씬 밝고 활기찼다. 깔끔한 원목 테이블 위에는 윤기가 흐르는 쌀밥과 갓 지은 반찬들이 정갈하게 놓여 있었다.
#
# "어서 와요, 총각! 여기 앉아."
#
# 앞치마를 두른 동네 할머니 한 분이 인자한 미소로 민우를 이끌었다. 대기업 임원 출신으로 보이는 정장 차림의 신사, 인근 대학의 유학생, 아기를 안은 젊은 엄마, 그리고 가방을 멘 초등학생까지. 다양한 사람들이 한 테이블에 둘러앉아 있었다.
#
# 어색하게 자리에 앉은 민우에게 식판이 배달되었다. 뜨끈한 흰쌀밥, 고기가 듬뿍 들어간 김치찌개, 바삭한 김, 그리고 봄나물 무침.
#
# 조심스럽게 찌개 국물을 한 숟가락 떠먹은 민우는 자신도 모르게 "아..." 하고 탄성을 내뱉었다. 인공적인 조미료 맛이 아니었다. 엄마가 해주던, 아니 그보다 더 깊은 손맛이 느껴지는 따뜻한 맛이었다.
#
# "맛있지?"
# 맞은편에 앉은 신사가 말을 건넸다. 은퇴 후 이웃들과 대화할 기회가 없었다는 그는 이 프로젝트 덕분에 매일 정오가 기다려진다고 했다.
# "이 밥 한 끼가 공짜 같지만, 사실 공짜가 아니에요. 저기 저 나물은 앞집 김 씨가 주말농장에서 기부한 거고, 저 김치는 뒤편 반찬가게 사장님이 비법을 전수해 준 거라더군. 우리는 서로의 온기를 나누어 먹고 있는 셈이지."
#
# 민우는 밥을 우물거리며 주변을 둘러보았다.
# 스마트폰만 들여다보던 사람들이 서로의 눈을 맞추며 웃고 있었고, 처음 보는 이들이 자연스럽게 반찬을 건네며 안부를 물었다. 매일 외롭게 모니터 앞에서 밥을 삼키던 민우의 가슴속으로 뜨거운 무언가가 흘러내렸다.
#
# 그것은 단순히 배를 채우는 포만감이 아니었다. 이 사회의 일원으로서 연결되어 있다는 안도감, 그리고 '따뜻함'이었다.
#
# 식사를 마치고 나오는 길, 민우는 식당 입구에 붙은 '자원봉사자 모집' 게시판 앞에서 걸음을 멈췄다. 그리고 주머니에서 펜을 꺼내 매주 토요일 오전 시간에 자신의 이름을 적어 넣었다.
#
# 점심 한 끼가 세상을 바꿀 수 있을까?
# 민우는 하늘을 올려다보며 미소를 지었다. 적어도 그의 세상은 오늘부터 조금 더 따뜻해질 것 같았다. 전국에 불어온 온기 프로젝트는, 그렇게 사람들의 얼어붙은 마음을 하나씩 녹여가고 있었다.None

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('경제 전공으로 사회에서 살아남는 데 필요한 기술 목록', model_name='google/gemini-2.5-flash', stream=True):
  wrapper.print(chunk)
# Out:
# 경제학 전공자가 사회에서 성공적으로 살아남기 위해 필요한 기술들은 단순히 이론적 지식을 넘어, 실제 문제 해결 능력, 데이터 활용 능력, 그리고
# 뛰어난 의사소통 능력 등을 아우릅니다. 다음은 핵심적인 기술 목록입니다.
#
# ---
#
# ### 경제 전공자에게 필요한 핵심 기술 목록
#
# **1. 심층적인 경제학적 사고력 및 분석 능력 (Core Economic Thinking & Analysis)**
#
# * **미시/거시 경제 이론 이해 및 적용:** 시장 작동 원 리, 기업 전략, 정부 정책 효과, 경제 성장, 인플레이션 등 광범위한 경제
# 현상을 이해하고 분석하는 능력.
# * **계량경제학적 분석 능력:** 통계학적 방법을 이용해 경제 데이터를 분석하고, 인과관계를 추론하며, 예측 모델을 구축 하는 능력. (예:
# 회귀 분석, 시계열 분석)
# * **정책 분석 및 평가:** 특정 경제 정책의 의도, 효과, 부작용 등을 다각적으로 분석하고 평가하여 합리적인 대안을 제시하는 능력.
# * **비판적 사고 (Critical Thinking): ** 주어진 정보나 주장을 맹목적으로 받아들이지 않고, 그 배경과 가정, 한계를
# 파악하며 논리적 오류를 찾아내는 능력.
#
# **2. 데이터 활용 및 분석 능력 (Data Utilization & Analysis)**
#
# * **데이터 수집 및 정제:** 필요한 데이터를 찾아내고( 공공 데이터, 기업 데이터 등), 분석 가능한 형태로 가공하고 정제하는 능력.
# * **통계 소프트웨어 활용:** R, Python(pandas, numpy, scikit-learn 등), Stata, SAS, SPSS 등
# 통계 및 데이터 분석 전문 소프트웨어를 능숙하게 다루는 능력.
# * **데이터 시각화:** 복잡한 데이터를 차트, 그래프, 대시보드 등을 활용하여 직관적으로 이해하기 쉽게 표현하는 능력. (예:
# Tableau, Power BI, Matplotlib, Seaborn)
# * **데이터베이스 활용 (SQL):** 대규모 데이터를 효율적으로 추출 하고 관리하기 위한 SQL(Structured Query
# Language) 사용 능력.
# * **스프레드시트 마스터 (Excel):** 단순한 계산을 넘어, 함수, 피벗 테이블, 조건부 서식, 매크로 등을 활용하여 데이터 분석 및
# 모델링을 수행하는 능력.
#
# **3. 문제 해결 및 의사 결정 능력 (Problem Solving & Decision Making)**
#
# * **문제 정의 및 구조화:** 모호하고 복잡한 현실 문제를 명확하게 정의하고, 분석 가능한 하위 문제로 분해하는 능력.
# * **가설 설정 및 검증:** 문제 해결을 위한 잠 정적인 가설을 설정하고, 데이터를 기반으로 이를 검증하거나 반박하는 능력.
# * **의사 결정 프레임워크:** 제한된 정보와 불확실성 속에서 합리적인 의사 결정을 내릴 수 있는 체계적인 사고방식 (예: 비용- 편익 분석,
# 리스크 관리).
# * **모델링 능력:** 현실의 복잡한 현상을 단순화하여 분석 가능한 모델로 만들고, 이를 통해 미래를 예측하거나 대안의 효과를 시뮬레이션하는
# 능력.
#
# **4. 커뮤니케이션 및 설득 능력 (Communication & Persuasion )**
#
# * **구두 발표 및 설명 능력:** 복잡한 경제 개념이나 분석 결과를 비전문가도 이해하기 쉽게 명확하고 간결하게 설명하는 능력.
# * **문서 작성 능력:** 보고서, 제안서, 연구 논문 등 목적에 맞춰 논리적이고 설 득력 있는 문서를 작성하는 능력. (파워포인트, 워드 등
# 활용)
# * **데이터 스토리텔링:** 단순히 데이터를 나열하는 것을 넘어, 데이터가 담고 있는 의미와 인사이트를 이야기처럼 풀어서 전달하는 능력.
# * **경청 및 질문:** 타인의 의견을 경청하고, 본질을 꿰뚫는 질문을 통해 문제의 핵심을 파악하는 능력.
#
# **5. 비즈니스 통찰력 및 산업 이해 (Business Acumen & Industry Understanding)**
#
# * **산업 분석:** 특정 산업의 구조, 경쟁 환경, 주요 동 향, 규제 등을 깊이 있게 이해하는 능력.
# * **시장 이해:** 소비자 행동, 경쟁사의 전략, 기술 변화 등이 시장에 미치는 영향을 파악하는 능력.
# * **재무 및 회계 기본 지식:** 기업의 재무제표를 이해하고, 기본적인 재무 분석을 통해 기업 가치나 건전성을 평가할 수 있는 능력.
# * **거시 경제와 기업/산업의 연관성 파악:** 금리 변화, 환율 변동, 정부 정책 등이 특정 기업이나 산업에 미치는 영향을 분석하는 능력.
#
# **6. 소프트 스킬 ( Soft Skills)**
#
# * **협업 능력:** 팀원들과 효과적으로 소통하고 협력하여 공동의 목표를 달성하는 능력.
# * **적응력 및 유연성:** 빠르게 변화하는 환경에 맞춰 새로운 지식과 기술을 습득하고, 사고방식을 유연하게 조 절하는 능력.
# * **자기 주도적 학습 능력:** 끊임없이 새로운 이론, 분석 기법, 기술을 스스로 찾아 배우고 발전시키는 능력.
# * **시간 관리 및 우선순위 설정:** 주어진 시간 내에 여러 업무의 우선순위를 정하고 효율적으로 관리하는 능력.
# * **윤리 의식 및 책임감:** 데이터 분석 및 활용에 있어 윤리적 기준을 준수하고, 맡은 업무에 대한 책임감을 갖는 능력.
#
# ---
#
# 경제학 전공자에게는 이 모든 기술들을 동시에 완벽하게 갖추기 어렵지만, 위 목록에서 자신에게 부족 한 부분을 인지하고 꾸준히 개발해 나가는 것이
# 중요합니다. 특히, **데이터 기반의 문제 해결 능력**과 **이를 효과적으로 전달하는 커뮤니케이션 능력**은 현대 사회에서 경제 전공자가 가장
# 강력하게 내세울 수 있는 무기가 될 것입니다.
